# %% [markdown]
# # People Report Data

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
#format: [DB_FLAVOR]+[DB_PYTHON_LIBRARY]://[USERNAME]:[PASSWORD]@[DB_HOST]:[PORT]/[DB_NAME]
engine = create_engine('mysql+mysqlconnector://cnguyen:Imq2MPSzsF5wdd8fBGA@hr-api-production-replica.cdq4e1fn5i6m.ca-central-1.rds.amazonaws.com/humi')

# %% [markdown]
# ## Salary

# %% [markdown]
# ### avg salary in 2020 and 2021

# %%
salary_query = "select salaries.employee_id, salaries.rate, salaries.frequency, effective_at, ends_at, \
salaries.hours_per_week, employees.company_id,employees.hired_at, employees.employment_type, \
employees.legal_sex \
from salaries \
left join `employees` on employees.id = salaries.employee_id \
left join `companies` on companies.id = employees.company_id \
where companies.deleted_at is null and hired_at > '2019-12-31 23:59:59' and ends_at != '0002-01-01' \
and salaries.hours_per_week > 0 and salaries.deleted_at is null"

# %%
salary = pd.read_sql_query(salary_query,con=engine)

# %%
salary = salary.astype({'effective_at':'datetime64','ends_at':'datetime64','rate':float})
salary = salary[salary['rate']>9]

# %%
salary.loc[salary['frequency']=='hour','rate'] = salary['rate']*salary['hours_per_week']*52
# the minimum wage in Canada is 11.45, any annual salary lower than 11.45*52 will be invaild assuming people work 
#at least one hour per week
salary.loc[((salary['frequency']=='year')&(salary['rate']<595.4)),'valid']="n/a"
salary.loc[((salary['frequency']=='hour')&(salary['rate']>1000)),'valid']="n/a"

# %%
salary = salary.loc[salary['valid']!="n/a"]

# %% [markdown]
# ### full time employees

# %%
salary_df = salary.copy()

# %%
salary_df = salary_df[salary_df['employment_type']=='full-time']

# %%
Jan_2020_f = salary_df[salary_df['effective_at']<'2020-01-31 23:59:59']
Jan_2020_f.loc[((Jan_2020_f['ends_at']>'2020-01-31 23:59:59')),"live data"] = True
Jan_2020_f = Jan_2020_f[Jan_2020_f['live data'] == True]
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
Jan_2020_f.mean()
# Out:
# <ipython-input-104-601945b497c8>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jan_2020_f.mean()
# employee_id       35493.931034
# rate              76807.825985
# hours_per_week       39.496330
# company_id          973.842365
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jan_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  62518.789116
# 1         M  91734.315377
# 2         P  59519.614545

# %%
Feb_2020_f = salary_df[salary_df['effective_at']<'2020-02-29 23:59:59']

Feb_2020_f.loc[((Feb_2020_f['ends_at']>'2020-02-29 23:59:59')),"live data"] = True

Feb_2020_f = Feb_2020_f[Feb_2020_f['live data'] == True]
Feb_2020_f.mean()
# Out:
# <ipython-input-105-3bbd5c0d1f05>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Feb_2020_f.mean()
# employee_id       36165.148092
# rate              85307.952489
# hours_per_week       39.744046
# company_id          987.712977
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Feb_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex           rate
# 0         F   60549.827631
# 1         M  109986.673283
# 2         P   63051.131429

# %%
Mar_2020_f = salary_df[salary_df['effective_at']<'2020-03-31 23:59:59']

Mar_2020_f.loc[((Mar_2020_f['ends_at']>'2020-03-31 23:59:59')),"live data"] = True

Mar_2020_f = Mar_2020_f[Mar_2020_f['live data'] == True]
Mar_2020_f.mean()
# Out:
# <ipython-input-106-12122945e4dc>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Mar_2020_f.mean()
# employee_id       37073.259786
# rate              85373.748185
# hours_per_week       39.638019
# company_id          996.141163
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Mar_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex           rate
# 0         F   68435.021186
# 1         M  102838.488829
# 2         P   59504.652143

# %%
Apr_2020_f = salary_df[salary_df['effective_at']<'2020-04-30 23:59:59']

Apr_2020_f.loc[((Apr_2020_f['ends_at']>'2020-04-30 23:59:59')),"live data"] = True

Apr_2020_f = Apr_2020_f[Apr_2020_f['live data'] == True]
Apr_2020_f.mean()
# Out:
# <ipython-input-107-704c794a74e6>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Apr_2020_f.mean()
# employee_id       37351.857294
# rate              84910.674524
# hours_per_week       39.642378
# company_id         1000.745243
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Apr_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex           rate
# 0         F   67837.134532
# 1         M  101636.556201
# 2         P   62718.937857

# %%
May_2020_f = salary_df[salary_df['effective_at']<'2020-05-31 23:59:59']

May_2020_f.loc[((May_2020_f['ends_at']>'2020-05-31 23:59:59')),"live data"] = True

May_2020_f = May_2020_f[May_2020_f['live data'] == True]
May_2020_f.mean()
# Out:
# <ipython-input-108-0fba07b82169>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   May_2020_f.mean()
# employee_id       38138.520258
# rate              80303.756188
# hours_per_week       39.552357
# company_id         1012.093002
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
May_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  68058.113543
# 1         M  92249.492473
# 2         P  66114.235000

# %%
Jun_2020_f = salary_df[salary_df['effective_at']<'2020-06-30 23:59:59']

Jun_2020_f.loc[((Jun_2020_f['ends_at']>'2020-06-30 23:59:59')),"live data"] = True

Jun_2020_f = Jun_2020_f[Jun_2020_f['live data'] == True]
Jun_2020_f.mean()
# Out:
# <ipython-input-109-62928e51c659>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jun_2020_f.mean()
# employee_id       38897.808230
# rate              77305.596817
# hours_per_week       39.537671
# company_id         1023.555124
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jun_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  63041.817758
# 1         M  90080.821131
# 2         P  64689.436316

# %%
Jul_2020_f = salary_df[salary_df['effective_at']<'2020-07-31 23:59:59']

Jul_2020_f.loc[((Jul_2020_f['ends_at']>'2020-07-31 23:59:59')),"live data"] = True

Jul_2020_f = Jul_2020_f[Jul_2020_f['live data'] == True]
Jul_2020_f.mean()
# Out:
# <ipython-input-110-eaf9a0e78cba>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jul_2020_f.mean()
# employee_id       39603.944444
# rate              81761.319527
# hours_per_week       39.563162
# company_id         1032.947874
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jul_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  66502.201823
# 1         M  95075.152166
# 2         P  64426.278421

# %%
Aug_2020_f = salary_df[salary_df['effective_at']<'2020-08-31 23:59:59']

Aug_2020_f.loc[((Aug_2020_f['ends_at']>'2020-08-31 23:59:59')),"live data"] = True

Aug_2020_f = Aug_2020_f[Aug_2020_f['live data'] == True]
Aug_2020_f.mean()
# Out:
# <ipython-input-111-d780844733d8>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Aug_2020_f.mean()
# employee_id       41224.150327
# rate              85810.049133
# hours_per_week       39.630582
# company_id         1055.792038
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Aug_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  75656.082790
# 1         M  95612.301516
# 2         P  62748.964500

# %%
Sept_2020_f = salary_df[salary_df['effective_at']<'2020-09-30 23:59:59']

Sept_2020_f.loc[((Sept_2020_f['ends_at']>'2020-09-30 23:59:59')),"live data"] = True

Sept_2020_f = Sept_2020_f[Sept_2020_f['live data'] == True]
Sept_2020_f.mean()
# Out:
# <ipython-input-112-d584cb284858>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Sept_2020_f.mean()
# employee_id       42487.548710
# rate              81190.227357
# hours_per_week       39.662033
# company_id         1076.702475
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Sept_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  76877.374675
# 1         M  86161.999097
# 2         P  62748.964500

# %%
Oct_2020_f = salary_df[salary_df['effective_at']<'2020-10-31 23:59:59']

Oct_2020_f.loc[((Oct_2020_f['ends_at']>'2020-10-31 23:59:59')),"live data"] = True

Oct_2020_f = Oct_2020_f[Oct_2020_f['live data'] == True]
Oct_2020_f.mean()
# Out:
# <ipython-input-113-f7633c0a8262>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Oct_2020_f.mean()
# employee_id       43797.739679
# rate              83048.537912
# hours_per_week       39.499694
# company_id         1093.300631
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Oct_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  80778.863462
# 1         M  86163.854392
# 2         P  62617.331053

# %%
Nov_2020_f = salary_df[salary_df['effective_at']<'2020-11-30 23:59:59']

Nov_2020_f.loc[((Nov_2020_f['ends_at']>'2020-11-30 23:59:59')),"live data"] = True

Nov_2020_f = Nov_2020_f[Nov_2020_f['live data'] == True]
Nov_2020_f.mean()
# Out:
# <ipython-input-114-74fac1fcda12>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Nov_2020_f.mean()
# employee_id       45255.113855
# rate              80403.545565
# hours_per_week       39.482529
# company_id         1118.557385
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Nov_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  75863.815263
# 1         M  85019.850017
# 2         P  72913.120526

# %%
Dec_2020_f = salary_df[salary_df['effective_at']<'2020-12-31 23:59:59']

Dec_2020_f.loc[((Dec_2020_f['ends_at']>'2020-12-31 23:59:59')),"live data"] = True

Dec_2020_f = Dec_2020_f[Dec_2020_f['live data'] == True]
Dec_2020_f.mean()
# Out:
# <ipython-input-115-68d6a5875861>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Dec_2020_f.mean()
# employee_id       46620.614982
# rate              78075.006679
# hours_per_week       39.496716
# company_id         1138.308539
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Dec_2020_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  73836.162275
# 1         M  82147.915767
# 2         P  76902.899412

# %%
Jan_2021_f = salary_df[salary_df['effective_at']<'2021-01-31 23:59:59']

Jan_2021_f.loc[((Jan_2021_f['ends_at']>'2021-01-31 23:59:59')),"live data"] = True

Jan_2021_f = Jan_2021_f[Jan_2021_f['live data'] == True]
Jan_2021_f.mean()
# Out:
# <ipython-input-116-07eeb9121c09>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jan_2021_f.mean()
# employee_id       48696.370543
# rate              77777.167183
# hours_per_week       39.533292
# company_id         1191.308010
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jan_2021_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  70089.330165
# 1         M  84883.093268
# 2         P  73615.580625

# %%
Feb_2021_f = salary_df[salary_df['effective_at']<'2021-02-28 23:59:59']

Feb_2021_f.loc[((Feb_2021_f['ends_at']>'2021-02-28 23:59:59')),"live data"] = True

Feb_2021_f = Feb_2021_f[Feb_2021_f['live data'] == True]
Feb_2021_f.mean()
# Out:
# <ipython-input-117-85ea6028ae29>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Feb_2021_f.mean()
# employee_id       50595.577691
# rate              79989.330422
# hours_per_week       39.407830
# company_id         1200.980577
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Feb_2021_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  74414.311020
# 1         M  85249.358638
# 2         P  69984.929000

# %%
Mar_2021_f = salary_df[salary_df['effective_at']<'2021-03-31 23:59:59']

Mar_2021_f.loc[((Mar_2021_f['ends_at']>'2021-03-31 23:59:59')),"live data"] = True

Mar_2021_f = Mar_2021_f[Mar_2021_f['live data'] == True]
Mar_2021_f.mean()
# Out:
# <ipython-input-118-5b2647007cd2>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Mar_2021_f.mean()
# employee_id       52867.744945
# rate              83130.426625
# hours_per_week       39.414631
# company_id         1218.095890
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Mar_2021_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  77448.674954
# 1         M  88219.486247
# 2         P  63872.143333

# %%
Apr_2021_f = salary_df[salary_df['effective_at']<'2021-04-30 23:59:59']

Apr_2021_f.loc[((Apr_2021_f['ends_at']>'2021-04-30 23:59:59')),"live data"] = True

Apr_2021_f = Apr_2021_f[Apr_2021_f['live data'] == True]
Apr_2021_f.mean()
# Out:
# <ipython-input-119-3c78426e8476>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Apr_2021_f.mean()
# employee_id       55014.864351
# rate              81267.494405
# hours_per_week       39.403002
# company_id         1256.146402
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Apr_2021_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  67196.754551
# 1         M  92818.168281
# 2         P  54641.548333

# %%
May_2021_f = salary_df[salary_df['effective_at']<'2021-05-31 23:59:59']

May_2021_f.loc[((May_2021_f['ends_at']>'2021-05-31 23:59:59')),"live data"] = True

May_2021_f = May_2021_f[May_2021_f['live data'] == True]
May_2021_f.mean()
# Out:
# <ipython-input-120-0377d4169178>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   May_2021_f.mean()
# employee_id       58158.925032
# rate              88036.704651
# hours_per_week       39.281512
# company_id         1343.944091
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
May_2021_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex           rate
# 0         F   72701.989848
# 1         M  100192.720837
# 2         P   55087.322500

# %%
Jun_2021_f = salary_df[salary_df['effective_at']<'2021-06-30 23:59:59']

Jun_2021_f.loc[((Jun_2021_f['ends_at']>'2021-06-30 23:59:59')),"live data"] = True

Jun_2021_f = Jun_2021_f[Jun_2021_f['live data'] == True]
Jun_2021_f.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-125-448b67a018ac>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jun_2021_f.mean()
# employee_id       60774.563380
# rate              66395.450176
# hours_per_week       39.319789
# company_id         1331.126761
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jun_2021_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  55019.412203
# 1         M  75239.600064
# 2         P  57000.000000

# %%
Jul_2021_f = salary_df[salary_df['effective_at']<'2021-07-30 23:59:59']

Jul_2021_f.loc[((Jul_2021_f['ends_at']>'2021-07-30 23:59:59')),"live data"] = True

Jul_2021_f = Jul_2021_f[Jul_2021_f['live data'] == True]
Jul_2021_f.mean()
# Out:
# <ipython-input-126-87f8174d6b5a>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jul_2021_f.mean()
# employee_id       63236.206349
# rate              59725.542063
# hours_per_week       38.929206
# company_id         1384.888889
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jul_2021_f.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  45637.165172
# 1         M  71742.098824

# %% [markdown]
# ## part time

# %%
salary_df_2 = salary.copy()

# %%
salary_df_2 = salary_df_2[salary_df_2['employment_type']=='part-time']

# %%
Jan_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-01-31 23:59:59']

Jan_2020_p.loc[((Jan_2020_p['ends_at']>'2020-01-31 23:59:59')),"live data"] = True

Jan_2020_p = Jan_2020_p[Jan_2020_p['live data'] == True]
Jan_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-154-20751cee4eb8>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jan_2020_p.mean()
# employee_id       26961.090909
# rate              44533.181818
# hours_per_week       27.545455
# company_id          502.000000
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jan_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  40315.200000
# 1         M  48048.166667

# %%
Feb_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-02-29 23:59:59']

Feb_2020_p.loc[((Feb_2020_p['ends_at']>'2020-02-29 23:59:59')),"live data"] = True

Feb_2020_p = Feb_2020_p[Feb_2020_p['live data'] == True]
Feb_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-184-62683307d666>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Feb_2020_p.mean()
# employee_id       27294.000000
# rate              45844.454545
# hours_per_week       26.000000
# company_id          558.909091
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Feb_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  43750.000000
# 1         M  47041.285714

# %%
Mar_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-03-31 23:59:59']

Mar_2020_p.loc[((Mar_2020_p['ends_at']>'2020-03-31 23:59:59')),"live data"] = True

Mar_2020_p = Mar_2020_p[Mar_2020_p['live data'] == True]
Mar_2020_p.mean()
# Out:
# <ipython-input-159-317178b6a227>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Mar_2020_p.mean()
# employee_id       27732.230769
# rate              43406.846154
# hours_per_week       28.884615
# company_id          565.923077
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Mar_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  43000.000000
# 1         M  43755.571429

# %%
Apr_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-04-30 23:59:59']

Apr_2020_p.loc[((Apr_2020_p['ends_at']>'2020-04-30 23:59:59')),"live data"] = True

Apr_2020_p = Apr_2020_p[Apr_2020_p['live data'] == True]
Apr_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-161-7e7586eed0b3>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Apr_2020_p.mean()
# employee_id       31908.312500
# rate              41899.439375
# hours_per_week       30.093750
# company_id          691.000000
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Apr_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  42783.333333
# 1         M  41369.103000

# %%
May_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-05-31 23:59:59']

May_2020_p.loc[((May_2020_p['ends_at']>'2020-05-31 23:59:59')),"live data"] = True

May_2020_p = May_2020_p[May_2020_p['live data'] == True]
May_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-163-00eb53289e6a>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   May_2020_p.mean()
# employee_id       35323.772727
# rate              41711.130455
# hours_per_week       29.840909
# company_id          818.727273
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
May_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  40617.573333
# 1         M  42468.208462

# %%
Jun_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-06-30 23:59:59']

Jun_2020_p.loc[((Jun_2020_p['ends_at']>'2020-06-30 23:59:59')),"live data"] = True

Jun_2020_p = Jun_2020_p[Jun_2020_p['live data'] == True]
Jun_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-165-cc4c2915c521>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jun_2020_p.mean()
# employee_id       36728.0400
# rate              37937.7948
# hours_per_week       29.2600
# company_id          860.3200
# valid                    NaN
# live data             1.0000
# dtype: float64

# %%
Jun_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  36596.196364
# 1         M  38991.907857

# %%
Jul_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-07-31 23:59:59']

Jul_2020_p.loc[((Jul_2020_p['ends_at']>'2020-07-31 23:59:59')),"live data"] = True

Jul_2020_p = Jul_2020_p[Jul_2020_p['live data'] == True]
Jul_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-167-008140217337>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jul_2020_p.mean()
# employee_id       38157.735294
# rate              35306.432647
# hours_per_week       30.750000
# company_id         1008.088235
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jul_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  36128.800000
# 1         M  34657.195263

# %%
Aug_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-08-31 23:59:59']

Aug_2020_p.loc[((Aug_2020_p['ends_at']>'2020-08-31 23:59:59')),"live data"] = True

Aug_2020_p = Aug_2020_p[Aug_2020_p['live data'] == True]
Aug_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-170-e7fe2e9a2004>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Aug_2020_p.mean()
# employee_id       41344.944444
# rate              33330.057500
# hours_per_week       29.888889
# company_id         1193.000000
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Aug_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  35464.802667
# 1         M  31145.501500
# 2         P  45000.000000

# %%
Sept_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-09-30 23:59:59']

Sept_2020_p.loc[((Sept_2020_p['ends_at']>'2020-09-30 23:59:59')),"live data"] = True

Sept_2020_p = Sept_2020_p[Sept_2020_p['live data'] == True]
Sept_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-172-0a5bb027110d>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Sept_2020_p.mean()
# employee_id       41632.194444
# rate              34257.128611
# hours_per_week       30.583333
# company_id         1154.805556
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Sept_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  32558.014286
# 1         M  33709.101500
# 2         P  45000.000000

# %%
Oct_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-10-31 23:59:59']

Oct_2020_p.loc[((Oct_2020_p['ends_at']>'2020-10-31 23:59:59')),"live data"] = True

Oct_2020_p = Oct_2020_p[Oct_2020_p['live data'] == True]
Oct_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-174-a9c1f60e0476>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Oct_2020_p.mean()
# employee_id       44841.326531
# rate              29749.230000
# hours_per_week       24.489796
# company_id         1240.346939
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Oct_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  29761.429091
# 1         M  27987.937200
# 2         P  45000.000000

# %%
Nov_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-11-30 23:59:59']

Nov_2020_p.loc[((Nov_2020_p['ends_at']>'2020-11-30 23:59:59')),"live data"] = True

Nov_2020_p = Nov_2020_p[Nov_2020_p['live data'] == True]
Nov_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-176-e0aa1110b975>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Nov_2020_p.mean()
# employee_id       48433.508475
# rate              28135.543559
# hours_per_week       24.186441
# company_id         1330.406780
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Nov_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  28779.132308
# 1         M  26079.910645
# 2         P  45000.000000

# %%
Dec_2020_p = salary_df_2[salary_df_2['effective_at']<'2020-12-31 23:59:59']

Dec_2020_p.loc[((Dec_2020_p['ends_at']>'2020-12-31 23:59:59')),"live data"] = True

Dec_2020_p = Dec_2020_p[Dec_2020_p['live data'] == True]
Dec_2020_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-178-4a3de5075dce>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Dec_2020_p.mean()
# employee_id       50300.489796
# rate              27589.332041
# hours_per_week       25.081633
# company_id         1386.489796
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Dec_2020_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  30930.472941
# 1         M  25195.459032
# 2         P  45000.000000

# %%
Jan_2021_p = salary_df_2[salary_df_2['effective_at']<'2021-01-31 23:59:59']

Jan_2021_p.loc[((Jan_2021_p['ends_at']>'2021-01-31 23:59:59')),"live data"] = True

Jan_2021_p = Jan_2021_p[Jan_2021_p['live data'] == True]
Jan_2021_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-181-1f2264f682c1>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jan_2021_p.mean()
# employee_id       53081.847458
# rate              30239.563220
# hours_per_week       24.508475
# company_id         1404.440678
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jan_2021_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  32742.687500
# 1         M  28420.761707
# 2         P  45000.000000

# %%
Feb_2021_p = salary_df_2[salary_df_2['effective_at']<'2021-02-28 23:59:59']

Feb_2021_p.loc[((Feb_2021_p['ends_at']>'2021-02-28 23:59:59')),"live data"] = True

Feb_2021_p = Feb_2021_p[Feb_2021_p['live data'] == True]
Feb_2021_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-186-540e571c8caa>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Feb_2021_p.mean()
# employee_id       53962.763636
# rate              26840.786000
# hours_per_week       23.018182
# company_id         1425.890909
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Feb_2021_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  28406.615385
# 1         M  25298.930750
# 2         P  45000.000000

# %%
Mar_2021_p = salary_df_2[salary_df_2['effective_at']<'2021-03-31 23:59:59']

Mar_2021_p.loc[((Mar_2021_p['ends_at']>'2021-03-31 23:59:59')),"live data"] = True

Mar_2021_p = Mar_2021_p[Mar_2021_p['live data'] == True]
Mar_2021_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-188-7c2ccebd2b74>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Mar_2021_p.mean()
# employee_id       57182.962963
# rate              29187.781481
# hours_per_week       22.796296
# company_id         1395.055556
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Mar_2021_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  31845.733333
# 1         M  27120.383784
# 2         P  45000.000000

# %%
Apr_2021_p = salary_df_2[salary_df_2['effective_at']<'2021-04-30 23:59:59']

Apr_2021_p.loc[((Apr_2021_p['ends_at']>'2021-04-30 23:59:59')),"live data"] = True

Apr_2021_p = Apr_2021_p[Apr_2021_p['live data'] == True]
Apr_2021_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-190-9289c6cf58b6>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Apr_2021_p.mean()
# employee_id       57607.365854
# rate              28897.531707
# hours_per_week       22.743902
# company_id         1395.536585
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Apr_2021_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  30475.846154
# 1         M  27356.029630

# %%
May_2021_p = salary_df_2[salary_df_2['effective_at']<'2021-05-31 23:59:59']

May_2021_p.loc[((May_2021_p['ends_at']>'2021-05-31 23:59:59')),"live data"] = True

May_2021_p = May_2021_p[May_2021_p['live data'] == True]
May_2021_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-192-d060817cb2d5>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   May_2021_p.mean()
# employee_id       59887.148148
# rate              32764.400000
# hours_per_week       26.722222
# company_id         1449.777778
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
May_2021_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  35467.333333
# 1         M  30319.576471

# %%
Jun_2021_p = salary_df_2[salary_df_2['effective_at']<'2021-06-30 23:59:59']

Jun_2021_p.loc[((Jun_2021_p['ends_at']>'2021-06-30 23:59:59')),"live data"] = True

Jun_2021_p = Jun_2021_p[Jun_2021_p['live data'] == True]
Jun_2021_p.mean()
# Out:
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/irisli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-196-2b5685859a7e>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jun_2021_p.mean()
# employee_id       64433.111111
# rate              32401.155556
# hours_per_week       27.333333
# company_id         1558.000000
# valid                      NaN
# live data             1.000000
# dtype: float64

# %%
Jun_2021_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex          rate
# 0         F  26816.000000
# 1         M  35193.733333

# %%
Jul_2021_p = salary_df_2[salary_df_2['effective_at']<'2021-07-31 23:59:59']

Jul_2021_p.loc[((Jul_2021_p['ends_at']>'2021-07-31 23:59:59')),"live data"] = True

Jul_2021_p = Jul_2021_p[Jul_2021_p['live data'] == True]
Jul_2021_p.mean()
# Out:
# <ipython-input-198-9d15e4b88d16>:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Jul_2021_p.mean()
# employee_id       69917.5
# rate              28180.5
# hours_per_week       35.0
# company_id         1859.5
# valid                 NaN
# live data             1.0
# dtype: float64

# %%
Jul_2021_p.groupby('legal_sex', as_index=False)["rate"].mean()
# Out:
#   legal_sex     rate
# 0         F  26816.0
# 1         M  32274.0

# %% [markdown]
# ### Salary Raise

# %%
salary_all_query = "select salaries.employee_id, salaries.rate, salaries.frequency, effective_at, ends_at, \
salaries.hours_per_week, employees.company_id,employees.hired_at, employees.employment_type, \
employees.legal_sex \
from salaries \
left join `employees` on employees.id = salaries.employee_id \
left join `companies` on companies.id = employees.company_id \
where companies.deleted_at is null and ends_at != '0002-01-01' \
and salaries.deleted_at is null"

# %%
salary_all = pd.read_sql_query(salary_all_query,con=engine)

# %%
salary_all_df = salary_all.copy()

# %%
len(salary_all_df['employee_id'].unique())
# Out:
# 30919

# %%
salary_all_df = pd.concat(g for _, g in salary_all_df.groupby("employee_id") if len(g) > 1)

# %%
salary_all_df = salary_all_df.astype({'effective_at':'datetime64','ends_at':'datetime64','rate':float})
salary_all_df = salary_all_df[salary_all_df['rate']>9]
salary_all_df.loc[salary_all_df['frequency']=='hour','rate'] = salary_all_df['rate']*salary_all_df['hours_per_week']*52
# the minimum wage in Canada is 11.45, any annual salary lower than 11.45*52 will be invaild assuming people work 
#at least one hour per week
salary_all_df.loc[((salary_all_df['frequency']=='year')&(salary_all_df['rate']<595.4)),'valid']="n/a"
salary_all_df.loc[((salary_all_df['frequency']=='hour')&(salary_all_df['rate']>1000)),'valid']="n/a"
salary_all_df = salary_all_df.loc[salary_all_df['valid']!="n/a"]

# %%
unique_id = salary_all_df['employee_id'].unique()

# %%
df_increase = pd.DataFrame()
df_amount_increase = pd.DataFrame()

for i in unique_id:
    temp = salary_all_df.loc[salary_all_df['employee_id'] == i]
    temp.sort_values(by='effective_at')
    temp["% change"] = temp['rate'].pct_change()
    df_amount_increase = df_amount_increase.append(temp)
    for j in range (len(temp.index)-1):
        if temp.iloc[j+1,1]>temp.iloc[j,1]:
            df_increase = df_increase.append(temp.iloc[j+1])
# Out:
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()
# <ipython-input-588-b241a19a701d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["% change"] = temp['rate'].pct_change()

# %%
df_amount_increase = df_amount_increase.astype({'effective_at':str})
df_amount_increase.effective_at = df_amount_increase.effective_at.str[0:4]

# %%
df_amount_increase = df_amount_increase.replace([np.inf, -np.inf], np.nan)
df_amount_increase = df_amount_increase.dropna(subset=['% change'])

# %%
import numpy as np
pd.pivot_table(df_amount_increase, values='% change', index = ["effective_at"], columns=['legal_sex'],aggfunc=np.mean)
# Out:
# legal_sex            F         M         P
# effective_at
# 1986         -0.148649       NaN       NaN
# 1990               NaN -0.088164       NaN
# 1994               NaN  0.045455       NaN
# 1995               NaN  0.026087       NaN
# 1996               NaN -0.480917       NaN
# 1997               NaN  0.073247       NaN
# 1998          0.069237  0.047921       NaN
# 1999          0.015003  0.089828       NaN
# 2000          0.029287  0.091705       NaN
# 2001          0.025762 -0.040438       NaN
# 2002         -0.021581  0.035064       NaN
# 2003         -0.185261 -0.155271       NaN
# 2004          0.141355 -0.046875       NaN
# 2005          0.014811  0.023880  0.030000
# 2006          0.151212  0.056424  0.323919
# 2007          0.095385  0.061550  0.180050
# 2008         -0.011880 -0.013395  0.072577
# 2009          0.040166 -0.005848  0.045000
# 2010         -0.013807 -0.006158  0.069072
# 2011          0.034366  0.022232  0.033293
# 2012          0.057971 -0.002312 -0.014230
# 2013          0.070880 -0.004914  0.074059
# 2014          0.005332  0.101993 -0.010919
# 2015          0.104439  0.004622  0.038751
# 2016          0.074445  0.022864  0.041297
# 2017          0.005748  0.061251  0.097508
# 2018          0.123904  0.145498  0.137768
# 2019          0.128420  0.161263  0.116515
# 2020          0.079936  0.117061  0.161384
# 2021          0.086030  0.228207  0.014171
# 2022               NaN  0.277778       NaN

# %%
df_increase = df_increase.astype({'effective_at':str})
df_increase.effective_at = df_increase.effective_at.str[0:4]

# %%
df_increase_final = df_increase.groupby(["effective_at","legal_sex"],as_index=False).size()
df_increase_final.pivot(index="effective_at",columns = 'legal_sex', values = "size")
# Out:
# legal_sex          F       M     P
# effective_at
# 1994             NaN     1.0   NaN
# 1995             NaN     1.0   NaN
# 1996             NaN     1.0   NaN
# 1997             NaN     4.0   NaN
# 1998             1.0     3.0   NaN
# 1999             1.0     5.0   NaN
# 2000             3.0     3.0   NaN
# 2001             3.0     4.0   NaN
# 2002             3.0     5.0   NaN
# 2003             3.0     5.0   NaN
# 2004             7.0     5.0   NaN
# 2005             7.0    10.0   1.0
# 2006            13.0    18.0   1.0
# 2007            19.0    17.0   1.0
# 2008            21.0    19.0   2.0
# 2009            24.0    27.0   2.0
# 2010            22.0    31.0   2.0
# 2011            29.0    33.0   2.0
# 2012            43.0    39.0   3.0
# 2013            52.0    54.0   3.0
# 2014            64.0    63.0   3.0
# 2015            80.0    86.0   4.0
# 2016           138.0   111.0   5.0
# 2017           159.0   172.0   7.0
# 2018           340.0   375.0  23.0
# 2019           901.0  1007.0  33.0
# 2020          1331.0  1607.0  36.0
# 2021           570.0   591.0  10.0
# 2022             NaN     1.0   NaN

# %% [markdown]
# ### Salary breakdown by province 2021

# %% [markdown]
# join address, company and employee datasets

# %%
# address_query = "select id, `province` from addresses \
# where `deleted_at` is NULL and country = 'Canada'"
# address = pd.read_sql_query(address_query, con=engine)
# address = address.rename(columns={"id":"address_id"})
# address = address.astype({"address_id": str})

# %%
# company_query = "select id, primary_address_id,industry from companies where deleted_at is null and is_locked = '0'"
# company = pd.read_sql_query(company_query, con=engine)
# company = company.rename(columns={"id":"company_id","primary_address_id":"address_id"})
# company = company.astype({"company_id":str,"address_id":str})
# company['address_id'] = company.apply(lambda x:x['address_id'].split('.')[0], axis=1)

# %%
# employee_query = "select id, company_id, legal_sex, account_id, hired_at from employees \
# where deleted_at is null and terminated_on is null and legal_sex is not null and hired_at > '2020-12-31 23:59:59'"
# employee = pd.read_sql_query(employee_query, con=engine)
# employee = employee.rename(columns={"id":"employee_id"})
# employee = employee.astype({"company_id": str,"employee_id":str})

# %%
# company_address = company.merge(address, how = "left", on = "address_id")

# %%
# employee_address = employee.merge(company_address, how = "left", on = "company_id")

# %%
# employee_address.groupby(["province"],as_index=False)["hours_per_week"].nunique()
